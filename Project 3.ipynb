# %%
import pandas as pd
# Out:
# [Errno 20] Not a directory: '/Users/swati/Desktop/july4_snapshot.csv'
# /Users/swati

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # 1. Exploratory Data Analysis

# %%
set1 = pd.read_csv("/Users/swati/Desktop/july4_snapshot.csv")
set1
# Out:
#       visitor  day_pass season_ticket  domestic  state country  gender  age  \
# 0           1         1            No         1     NY     USA       0   32
# 1           2         0           Yes         1  Other     USA       1   43
# 2           3         1            No         1     ME     USA       1   28
# 3           4         0           Yes         1     NH     USA       1   35
# 4           5         1            No         0    NaN     MEX       1   44
# ...       ...       ...           ...       ...    ...     ...     ...  ...
# 5211     5212         0           Yes         1     NH     USA       0   37
# 5212     5213         1            No         0    NaN      UK       1   30
# 5213     5214         0           Yes         1     NH     USA       1   36
# 5214     5215         0           Yes         1     ME     USA       0   38
# 5215     5216         1            No         1     MA     USA       0   35
#
# ...

# %% [markdown]
# *#A.*

# %%
set1.head()
# Out:
#    visitor  day_pass season_ticket  domestic  state country  gender  age  \
# 0        1         1            No         1     NY     USA       0   32
# 1        2         0           Yes         1  Other     USA       1   43
# 2        3         1            No         1     ME     USA       1   28
# 3        4         0           Yes         1     NH     USA       1   35
# 4        5         1            No         0    NaN     MEX       1   44
#
#   maine_res  stay_four  payment_method  ice_cream_purch ice_cream_flavor  \
# 0        No          1               0                1          Vanilla
# 1        No          1               0                1        Chocolate
# 2       Yes          1               0                0             None
# 3        No          0               0                0             None
# 4        No          1               0                1          Vanilla
#
#    sky_chair  ferris_wheel  lobster_claw  lobster_junior  merch_spend  \
# ...

# %% [markdown]
# *B. After running the head() function, 5 rows are visible in the data set as the head funtion gives us the top rows of the data set to get some understanding of what our data is about. We can alter the number of rows to be displayed by putting a numeric value inside the head function- head(9)*

# %% [markdown]
# *#c.*

# %%
set1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5216 entries, 0 to 5215
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   visitor           5216 non-null   int64
#  1   day_pass          5216 non-null   int64
#  2   season_ticket     5216 non-null   object
#  3   domestic          5216 non-null   int64
#  4   state             4127 non-null   object
#  5   country           5160 non-null   object
#  6   gender            5216 non-null   int64
#  7   age               5216 non-null   int64
#  8   maine_res         5216 non-null   object
#  9   stay_four         5216 non-null   int64
#  10  payment_method    5216 non-null   int64
#  11  ice_cream_purch   5216 non-null   int64
#  12  ice_cream_flavor  5216 non-null   object
#  13  sky_chair         5216 non-null   int64
#  14  ferris_wheel      5216 non-null   int64
#  15  lobster_claw      5216 non-null   int64
# ...

# %% [markdown]
# *There exists 5216 rows and 19 columns in my dataset as per the info() function with indexing of row as [0,5215]*

# %%
#d. 
set1
# Out:
#       visitor  day_pass season_ticket  domestic  state country  gender  age  \
# 0           1         1            No         1     NY     USA       0   32
# 1           2         0           Yes         1  Other     USA       1   43
# 2           3         1            No         1     ME     USA       1   28
# 3           4         0           Yes         1     NH     USA       1   35
# 4           5         1            No         0    NaN     MEX       1   44
# ...       ...       ...           ...       ...    ...     ...     ...  ...
# 5211     5212         0           Yes         1     NH     USA       0   37
# 5212     5213         1            No         0    NaN      UK       1   30
# 5213     5214         0           Yes         1     NH     USA       1   36
# 5214     5215         0           Yes         1     ME     USA       0   38
# 5215     5216         1            No         1     MA     USA       0   35
#
# ...

# %% [markdown]
# *a. state, country, gender, ice_cream_flavor are the variables that should be seen as categorical because these are the variables that would require string data type whereas visitor, day_pass, season_ticket, domestic, age, maine_res, stay_four, payment_method, ice_cream_purch, sky_chair, ferris_wheel, lobster_claw and lobster_junior should be numeric as they all represent integer values such as sky_chair will only have either 1 or 0 as its value and merch_spend, lobsterama_spend should be float as per the variable description. Some variables such as stay_four, ice_cream_punch could be treated as boolean data types too as it has only two values which could either be true or false.*

# %%
#E.
set2 = set1.round(decimals = 2)

# %%
set1['merch_spend'].round(decimals=2)
# Out:
# 0       34.53
# 1       23.81
# 2       49.23
# 3       55.51
# 4       61.02
#         ...
# 5211    51.13
# 5212    43.17
# 5213    37.49
# 5214    45.34
# 5215    46.31
# Name: merch_spend, Length: 5216, dtype: float64

# %%
set2
# Out:
#       visitor  day_pass season_ticket  domestic  state country  gender  age  \
# 0           1         1            No         1     NY     USA       0   32
# 1           2         0           Yes         1  Other     USA       1   43
# 2           3         1            No         1     ME     USA       1   28
# 3           4         0           Yes         1     NH     USA       1   35
# 4           5         1            No         0    NaN     MEX       1   44
# ...       ...       ...           ...       ...    ...     ...     ...  ...
# 5211     5212         0           Yes         1     NH     USA       0   37
# 5212     5213         1            No         0    NaN      UK       1   30
# 5213     5214         0           Yes         1     NH     USA       1   36
# 5214     5215         0           Yes         1     ME     USA       0   38
# 5215     5216         1            No         1     MA     USA       0   35
#
# ...

# %%
#F 
set2.isnull().sum()
# Out:
# visitor                0
# day_pass               0
# season_ticket          0
# domestic               0
# state               1089
# country               56
# gender                 0
# age                    0
# maine_res              0
# stay_four              0
# payment_method         0
# ice_cream_purch        0
# ice_cream_flavor       0
# sky_chair              0
# ferris_wheel           0
# lobster_claw           0
# lobster_junior         0
# merch_spend            0
# lobsterama_spend       0
# dtype: int64

# %% [markdown]
# *Yes, we have missing values in variable state, country. There are 1089 missing values in state column and 56 in country column. I used isnull() function to check if there exists any null value followed by sum() to check the missing values column wise.*

# %%
#a.
set3=set2[set2['state'].isna()]
set3
# Out:
#       visitor  day_pass season_ticket  domestic state country  gender  age  \
# 4           5         1            No         0   NaN     MEX       1   44
# 10         11         1            No         0   NaN     CAN       1   37
# 12         13         1            No         0   NaN     CHN       1   38
# 14         15         1            No         0   NaN     BRA       1   40
# 17         18         1            No         0   NaN     CAN       0   31
# ...       ...       ...           ...       ...   ...     ...     ...  ...
# 5202     5203         1            No         0   NaN     CAN       0   34
# 5205     5206         1            No         0   NaN     CAN       1   39
# 5206     5207         1            No         0   NaN     CHN       0   38
# 5207     5208         1            No         0   NaN     CAN       1   35
# 5212     5213         1            No         0   NaN      UK       1   30
#
# ...

# %%
set3.head(100)
# Out:
#      visitor  day_pass season_ticket  domestic state country  gender  age  \
# 4          5         1            No         0   NaN     MEX       1   44
# 10        11         1            No         0   NaN     CAN       1   37
# 12        13         1            No         0   NaN     CHN       1   38
# 14        15         1            No         0   NaN     BRA       1   40
# 17        18         1            No         0   NaN     CAN       0   31
# ..       ...       ...           ...       ...   ...     ...     ...  ...
# 533      534         0           Yes         0   NaN     FRA       1   35
# 534      535         1            No         0   NaN     JPN       1   39
# 542      543         0           Yes         0   NaN     BRA       0   35
# 547      548         1            No         0   NaN      UK       0   36
# 549      550         0           Yes         0   NaN     CAN       1   32
#
#     maine_res  stay_four  payment_method  ice_cream_purch ice_cream_flavor  \
# ...

# %% [markdown]
# *a. The important thing that is common in the dataframe 'set3' is that most, if not every, of them were not from United States which makes it clear that they were not a maine_resident and not domestic resident of US due to which there are NaN values (missing) in dataframe as it could be difficult for writing every homestate of international visitors.*

# %%
#G.
set2[set2['age'] < 16]
# Out:
#       visitor  day_pass season_ticket  domestic  state country  gender  age  \
# 1352     1353         0           Yes         1  Other     USA       1   14
#
#      maine_res  stay_four  payment_method  ice_cream_purch ice_cream_flavor  \
# 1352        No          1               1                1          Vanilla
#
#       sky_chair  ferris_wheel  lobster_claw  lobster_junior  merch_spend  \
# 1352          1             0             0               1        37.58
#
#       lobsterama_spend
# 1352             43.64

# %%
set2.loc[set2['age'] < 16, 'age']= 16

# %%
set2[set2['age'] < 16]
# Out:
# Empty DataFrame
# Columns: [visitor, day_pass, season_ticket, domestic, state, country, gender, age, maine_res, stay_four, payment_method, ice_cream_purch, ice_cream_flavor, sky_chair, ferris_wheel, lobster_claw, lobster_junior, merch_spend, lobsterama_spend]
# Index: []

# %%
set2.describe()
# Out:
#            visitor     day_pass     domestic       gender          age  \
# count  5216.000000  5216.000000  5216.000000  5216.000000  5216.000000
# mean   2608.500000     0.622316     0.791219     0.502109    36.302147
# std    1505.873833     0.484854     0.406476     0.500043     6.066898
# min       1.000000     0.000000     0.000000     0.000000    16.000000
# 25%    1304.750000     0.000000     1.000000     0.000000    32.000000
# 50%    2608.500000     1.000000     1.000000     1.000000    36.000000
# 75%    3912.250000     1.000000     1.000000     1.000000    40.000000
# max    5216.000000     1.000000     1.000000     1.000000    57.000000
#
#          stay_four  payment_method  ice_cream_purch    sky_chair  \
# count  5216.000000     5216.000000      5216.000000  5216.000000
# mean      0.599310        0.146089         0.312692     0.493098
# std       0.490085        0.353229         0.463634     0.500000
# min       0.000000        0.000000         0.000000     0.000000
# ...

# %% [markdown]
# *I used describe function to check the mimimum age which is now 16. This proves that we have altered the visitor with age below 16 to 16.*

# %%
#H.
#a.
set4=set2[set2['stay_four']==1]

# %%
set4
# Out:
#       visitor  day_pass season_ticket  domestic  state country  gender  age  \
# 0           1         1            No         1     NY     USA       0   32
# 1           2         0           Yes         1  Other     USA       1   43
# 2           3         1            No         1     ME     USA       1   28
# 4           5         1            No         0    NaN     MEX       1   44
# 7           8         0           Yes         1     VT     USA       0   29
# ...       ...       ...           ...       ...    ...     ...     ...  ...
# 5207     5208         1            No         0    NaN     CAN       1   35
# 5211     5212         0           Yes         1     NH     USA       0   37
# 5212     5213         1            No         0    NaN      UK       1   30
# 5214     5215         0           Yes         1     ME     USA       0   38
# 5215     5216         1            No         1     MA     USA       0   35
#
# ...

# %%
Pct_stay_four=(len(set4)/len(set2))*100
Pct_stay_four
# Out:
# 59.93098159509203

# %% [markdown]
# 59.93% guests stayed for more than 4 hours on July 4th in Lobster Land.

# %%
#b.
set5=set4[set4['domestic']==1]

# %%
pct_domestic=(len(set5)/len(set4))*100
pct_domestic
# Out:
# 68.71401151631477

# %% [markdown]
# *68.71% of guests were domestic and who stayed for more than 4 hours at Lobster Land on July 4th*

# %%
set6=set4[set4['domestic']==0]

# %%
pct_international= (len(set6)/len(set4))*100
pct_international
# Out:
# 31.285988483685223

# %%
pct_international+pct_domestic
# Out:
# 100.0

# %% [markdown]
# *31.29% guests were international guests who stayed for more than 4 hours in Lobster land on July 4th*

# %%
len(set6)
# Out:
# 978

# %%
len(set5)
# Out:
# 2148

# %% [markdown]
# *c.
# The values in step b were different. The length of rows for domestic guests were 2148 whereas the number of international guests were 978. There are various possible implications but what I think is-
# It is evident that domestic guests are more likely to go to lobster land as it is convenient for them to travel with low costs whereas it's expensive for international guests to come to lobster land. Also, it could be a small trip for domestic guests whereas international guests could find it difficult as the commute varies as per the distance and flight durations. One might spend a day or two at an adventure park if he/she lives in the same country but coming all the way from international country is obvious that they can miss out on adventure parks.*

# %%
#I.
#a. 
set2.head()
# Out:
#    visitor  day_pass season_ticket  domestic  state country  gender  age  \
# 0        1         1            No         1     NY     USA       0   32
# 1        2         0           Yes         1  Other     USA       1   43
# 2        3         1            No         1     ME     USA       1   28
# 3        4         0           Yes         1     NH     USA       1   35
# 4        5         1            No         0    NaN     MEX       1   44
#
#   maine_res  stay_four  payment_method  ice_cream_purch ice_cream_flavor  \
# 0        No          1               0                1          Vanilla
# 1        No          1               0                1        Chocolate
# 2       Yes          1               0                0             None
# 3        No          0               0                0             None
# 4        No          1               0                1          Vanilla
#
#    sky_chair  ferris_wheel  lobster_claw  lobster_junior  merch_spend  \
# ...

# %%
set7= set2

# %%
set7=set7.drop('domestic', 1)
# Out:
# /var/folders/xx/5d2tpx8j1rj_18ksbxgx9c400000gn/T/ipykernel_5163/3111507056.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   set7=set7.drop('domestic', 1)

# %%
set7
# Out:
#       visitor  day_pass season_ticket  state country  gender  age maine_res  \
# 0           1         1            No     NY     USA       0   32        No
# 1           2         0           Yes  Other     USA       1   43        No
# 2           3         1            No     ME     USA       1   28       Yes
# 3           4         0           Yes     NH     USA       1   35        No
# 4           5         1            No    NaN     MEX       1   44        No
# ...       ...       ...           ...    ...     ...     ...  ...       ...
# 5211     5212         0           Yes     NH     USA       0   37        No
# 5212     5213         1            No    NaN      UK       1   30        No
# 5213     5214         0           Yes     NH     USA       1   36        No
# 5214     5215         0           Yes     ME     USA       0   38       Yes
# 5215     5216         1            No     MA     USA       0   35        No
#
# ...

# %% [markdown]
# *i.
# The variable domestic is a redundant because it could already be understandable from the country variable that whather a guest came from some other country or the guest is from United states.
# The variable domestic can also be redundant because maine_res explains if a guest is a Maine resident or not. So it is clear if the guest is a Maine resident, he/she must be a domestic guest.*

# %%
#J.
#a.
set7.rename(columns = {"visitor" : "VistorId"}, inplace=True)
set7.head()
# Out:
#    VistorId  day_pass season_ticket  state country  gender  age maine_res  \
# 0         1         1            No     NY     USA       0   32        No
# 1         2         0           Yes  Other     USA       1   43        No
# 2         3         1            No     ME     USA       1   28       Yes
# 3         4         0           Yes     NH     USA       1   35        No
# 4         5         1            No    NaN     MEX       1   44        No
#
#    stay_four  payment_method  ice_cream_purch ice_cream_flavor  sky_chair  \
# 0          1               0                1          Vanilla          1
# 1          1               0                1        Chocolate          0
# 2          1               0                0             None          1
# 3          0               0                0             None          0
# 4          1               0                1          Vanilla          0
#
# ...

# %% [markdown]
# *I used rename() function for renaming my visitor variable from dataframe to VisitorId.*

# %% [markdown]
# # Part II: Data Visualization

# %%
#K.
plot1 = sns.boxplot(x='maine_res', y='merch_spend', data=set7)
plot1
# Out:
# <AxesSubplot:xlabel='maine_res', ylabel='merch_spend'>

# %% [markdown]
# *a. The median of guests who were maine resident spent less as compared to the guests who were not maine residents. This actually fit according to me because maine residents could be used to with going to Lobster land more often so they might not want to spend everytime they go there whereas international guests could have gone to lobster land for the first time and they might be willing to spending more on merchandize as a souvenir.*

# %%
#L
set8= set7
set8['sky_chair'].sum()
# Out:
# 2572

# %%
set8['ferris_wheel'].sum()
# Out:
# 2473

# %%
set8['lobster_claw'].sum()
# Out:
# 1447

# %%
set8['lobster_junior'].sum()
# Out:
# 2104

# %% [markdown]
# *sky_chair was the most popular ride and lobster_claw was the least popular ride on July 4th, 2021. I ran a sum function to calculate the total of each ride (column) to check the one with maximum sum. (maximum sum means more 1's in which 1 mean visitor who went on a particular ride. *

# %%
set9 = pd.DataFrame(
    [['sky_chair', 2572],
    ['ferris_wheel', 2473],
    ['lobster_claw', 1447],
    ['lobster_junior',2104]],
    columns=['RideType', 'Visitors'])
set9
# Out:
#          RideType  Visitors
# 0       sky_chair      2572
# 1    ferris_wheel      2473
# 2    lobster_claw      1447
# 3  lobster_junior      2104

# %%
plot2 = sns.barplot(x='RideType', y='Visitors', data= set9)

# %% [markdown]
# *a. This plot shows that sky_chair was the most popular ride, which means more amount of guests went on sky_chair ride as compared to others. Also, ferris_wheel is the second most popular ride. The least popular ride was lobster_claw which means it was the least used ride amongst other rides.*

# %%
#M.
plot3= plt.hist(set7['merch_spend'])

# %% [markdown]
# *We can increase a. the bins in a histogram by mentioning bins inside the plt.hist() function. The code is displayed above to see that.*

# %%
#b. 
plot4 = plt.hist(set7['merch_spend'], bins= 23)
plt.xlabel('Merchandize Spending')
plt.title('Merchandize spending per visitor')
# Out:
# Text(0.5, 1.0, 'Merchandize spending per visitor')

# %% [markdown]
# *c. plot4 is differentfrom plot3 because it displays even more insight about the mean and standard deviation of merchandize spend by each visitor. By increasing the number of bins, I was able to find the distribution of spending in a more detailed manner. By this we group our data more extensively and we can see the deviations from mean more thoroughly.*

# %%
#d.
plot5 = sns.histplot(x='merch_spend', hue='domestic', data= set2, multiple='stack')

# %% [markdown]
# *plot5 shows the distribution of merchandize spend per visitor along with showing difference in distributions of visistors based on location (domestic or international).*

# %%
#N.
set10=set2[set2['domestic']==1]
plot6= sns.countplot(x = 'state',
              data = set10,
              order = set10['state'].value_counts().index)

# %% [markdown]
# *a. This graph displays the count of visitors per state in Lobster land on July 4th in a decreasing order. It depicts that ME had the highest count of visistors whereas RI had the lowest visitor count and NY, NH, VT, other had almost equal visitor count. The visitor count by state means the count of guests from different states.*

# %%
#O.
set11=set2[set2['lobster_claw']==1]
set12= set11.groupby(by=["country"]).sum().sort_values('lobster_claw') 
#used sort_values()function to sort my data into ascending order. 
set12= set12.reset_index()
set12
# Out:
#    country  visitor  day_pass  domestic  gender    age  stay_four  \
# 0      FRA    42892        11         0       7    458         11
# 1      GER    27318        12         0       7    439         10
# 2      MEX    31310        12         0       9    474         10
# 3      JPN    36166        15         0      10    584         14
# 4      ROK    32147        16         0       7    581         13
# 5      IND    46042        17         0       7    603         14
# 6       UK    96347        33         0      14   1324         31
# 7      BRA    93649        38         0      21   1368         36
# 8      CHN   126899        40         0      20   1609         40
# 9      CAN   192089        74         0      42   2703         69
# 10     USA  3022962       625      1155     577  41940        630
#
#     payment_method  ice_cream_purch  sky_chair  ferris_wheel  lobster_claw  \
# 0                3                2          7             8            12
# ...

# %%
set13= set12.filter(['country','lobster_claw'], axis=1)


set13
# Out:
#    country  lobster_claw
# 0      FRA            12
# 1      GER            13
# 2      MEX            13
# 3      JPN            16
# 4      ROK            16
# 5      IND            17
# 6       UK            35
# 7      BRA            39
# 8      CHN            44
# 9      CAN            74
# 10     USA          1155

# %%
plot7= sns.barplot(x= 'country', y= 'lobster_claw', data=set13)

# %% [markdown]
# *b. this graphs depicts the country wise visitor count who rode on lobster_claw ride. It is evident that most of the guests who rode lobster_claw were USA citizens. The leaxt guests who rode lobster_claw was from France. Germany, Mexico, Japan had similar number of guests who rode the ride. Canada is the second highest country from hwere the guests came and rode the lobster_claw but it is still negligible as compared to guests from USA.*

# %% [markdown]
# # Part III

# %% [markdown]
# *A.*
#
# *a. I measured my daily calorie burnt through my apple watch.*
#
#
# *b. My breakdown for active calories for three consectutive days while working out is as follows-*
#
# *1st day- 314 cal*
#
# *2nd day- 427 cal*
#
# *3rd day- 412 cal*
#
#
# *c. While keeping track of my calorie burn for three days, it was really helpful in many aspects. On the first day when I started monitoring my calorie burn, I felt I am not burning enough calories as it is a scietific fact that in order to loose fat, we need to burn more calories than calorie intake. I was able to make a new diet chart in order to go slightly calorie deficit with nutritional division. Then, instead of lifting more weights and doing less repetetions, I started lifiting less and more repetetion. I started to have more stamina as compared to my last approach. This has also helped in faster heart rate which is a sign of more fat reduction, and indeed more calorie burn. On the second day, I burnt 427 calories and on subsequent third day I burnt 412 calories. Now I can feel that keeping track of my calorie intake and calorie burn can help me in achieving the desired body fat percentage. Also, I can alter my workout duration and style with the help of increment and decrement in calorie burn. I am going to follow this for another 2 months to see some results. If this would prove to be effective, I will use this metric in my life for a longer period of time until I become proficient without keeping a track. The overall impact of measuring this metric is that I started calculating through analzying facts rather than just what Ii heard from other people for losing fat. Self calculation and analysis could help in calculated prediction (time required in reaching to desired fat percentage) and modifications which comes in the my daily data of calorie burn.*
#
# *I can devide that further such as-*
#
# *-If I start recording my monthly or yearly data for calorie burn, I can see what was the pace of fat reduction if I start to monitor my fat percentage too. With the help of this, I can further predict how much fat percent can I reduce in a certain time period.*
#
# *-Accordinly I can start making my personalized diet charts. And monitoring the fat percentage with same or different style of workout, I can analyze which type of diet is required for what type of body goal.*
